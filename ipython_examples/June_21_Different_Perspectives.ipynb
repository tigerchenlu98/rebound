# %%
import rebound
sim=rebound.Simulation()
sim.add(m=1.)
#sim.add(m=1, a=300, e=0.05)
#sim.move_to_com()
sim.integrator="whfast"
sim.dt=0.05
sim.status()
#test
# Out:
# ---------------------------------
# REBOUND version:     	3.24.3
# REBOUND built on:    	Jun  7 2023 11:11:24
# Number of particles: 	1
# Selected integrator: 	whfast
# Simulation time:     	0.0000000000000000e+00
# Current timestep:    	0.050000
# ---------------------------------
# <rebound.particle.Particle object at 0x7f60516ac1c0, m=1.0 x=0.0 y=0.0 z=0.0 vx=0.0 vy=0.0 vz=0.0>
# ---------------------------------

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
Testparticle= 100
a_initial=np.linspace(10,50,Testparticle)
for a in a_initial:
    sim.add(a=a,f=np.random.rand()*2.*np.pi,e=0.01)

sim.add(m=1, a=300,e=0.05)

sim.N_active=2

plt.scatter(sim.particles[0].x, sim.particles[0].y,marker=".",color='r',linewidth=5)
plt.scatter(sim.particles[-1].x, sim.particles[-1].y,marker=".",color='g',linewidth=5)
ax=plt.subplot()
ax.set_ylabel("Major Axis Distance (AU)")
ax.set_xlabel("Distance (AU)")
for j in range(sim.N-2):
    i=j+1
    plt.scatter(sim.particles[i].x, sim.particles[i].y,marker=".",color='k',linewidth=0)

# %%
import rebound
sim=rebound.Simulation()
sim.add(m=1.)
#sim.add(m=1, a=300, e=0.05)
sim.integrator="whfast"
sim.dt=0.05
sim.status()
#test

import matplotlib.pyplot as plt

import numpy as np
Testparticle= 50
a_initial=np.linspace(10,50,Testparticle)
for a in a_initial:
    sim.add(a=a,f=np.random.rand()*2.*np.pi,e=0.01,)

sim.add(m=1, a=300,e=0.05)

sim.N_active=2
sim.move_to_com()
plt.scatter(sim.particles[0].x, sim.particles[0].z,marker=".",color='r',linewidth=5)
plt.scatter(sim.particles[-1].x, sim.particles[-1].z,marker=".",color='g',linewidth=5)

for j in range(sim.N-2):
    i=j+1
    plt.scatter(sim.particles[i].x, sim.particles[i].z,marker=".",color='k',linewidth=0)
# Out:
# ---------------------------------
# REBOUND version:     	3.24.3
# REBOUND built on:    	Jun  7 2023 11:11:24
# Number of particles: 	1
# Selected integrator: 	whfast
# Simulation time:     	0.0000000000000000e+00
# Current timestep:    	0.050000
# ---------------------------------
# <rebound.particle.Particle object at 0x7f6050a65ac0, m=1.0 x=0.0 y=0.0 z=0.0 vx=0.0 vy=0.0 vz=0.0>
# ---------------------------------

# %%
import rebound
sim=rebound.Simulation()
sim.add(m=1.)
#sim.add(m=1, a=300, e=0.05)
#sim.move_to_com()
sim.integrator="whfast"
sim.dt=0.05


import rebound
sim=rebound.Simulation()
sim.add(m=1.)
#sim.add(m=1, a=300, e=0.05)
#sim.move_to_com()
sim.integrator="whfast"
sim.dt=0.05
#test

import numpy as np
Testparticle= 50
a_initial=np.linspace(10,50,Testparticle)
for a in a_initial:
    sim.add(a=a,f=np.random.rand()*2.*np.pi,e=0.95,)

sim.add(m=1, a=300,e=0.05)
sim.add(m=10**-3, a=30,e=0.05)

sim.N_active=2

plt.scatter(sim.particles[0].x, sim.particles[0].y,marker=".",color='r',linewidth=5)
plt.scatter(sim.particles[-2].x, sim.particles[-1].y,marker=".",color='g',linewidth=5)
plt.scatter(sim.particles[-1].x, sim.particles[-1].y,marker=".",color='b',linewidth=3)

for j in range(sim.N-2):
    i=j+1
    plt.scatter(sim.particles[i].x, sim.particles[i].y,marker=".",color='k',linewidth=0)

# %%
# Edge on with companion inclination

import rebound
sim=rebound.Simulation()
sim.add(m=1.)
#sim.add(m=1, a=300, e=0.05)
#sim.move_to_com()
sim.integrator="whfast"
sim.dt=0.05
sim.status()
#test

import matplotlib.pyplot as plt

import numpy as np
Testparticle= 200
a_initial=np.linspace(10,50,Testparticle)
for a in a_initial:
    sim.add(a=a,f=np.random.rand()*2.*np.pi,e=0.01,inc=86)

sim.add(m=1, a=300,e=0.05, inc=76)

sim.N_active=2

plt.scatter(sim.particles[0].z, sim.particles[0].x,marker=".",color='r',linewidth=5)
plt.scatter(sim.particles[-1].z, sim.particles[-1].x,marker=".",color='g',linewidth=5)

for j in range(sim.N-2):
    i=j+1
    plt.scatter(sim.particles[i].z, sim.particles[i].x,marker=".",color='k',linewidth=0)
# Out:
# ---------------------------------
# REBOUND version:     	3.24.3
# REBOUND built on:    	Jun  7 2023 11:11:24
# Number of particles: 	1
# Selected integrator: 	whfast
# Simulation time:     	0.0000000000000000e+00
# Current timestep:    	0.050000
# ---------------------------------
# <rebound.particle.Particle object at 0x7f6050ad7ec0, m=1.0 x=0.0 y=0.0 z=0.0 vx=0.0 vy=0.0 vz=0.0>
# ---------------------------------

# %%
#Integrate with respect to Time

import rebound
sim=rebound.Simulation()
sim.add(m=1.)
#sim.add(m=1, a=300, e=0.05)
#sim.move_to_com()
sim.integrator="whfast"
sim.dt=0.05
#test

import matplotlib.pyplot as plt


import numpy as np
Testparticle= 50
a_initial=np.linspace(10,50,Testparticle)
for a in a_initial:
    sim.add(a=a,f=np.random.rand()*2.*np.pi,e=0)

sim.add(m=1, a=300,e=0.05,inc=np.radians(60))

sim.N_active=2


Time=100.*2*np.pi
N_out=100
xy=np.zeros((N_out,Testparticle,2))
times=np.linspace(0,Time,N_out)
for i, time in enumerate(times):
    sim.integrate(time, exact_finish_time=0)
    for j, p in enumerate(sim.particles[1:-1]):
        xy[i][j]=[p.x,p.y]

fig = plt.figure(figsize=(10,10))
plt.scatter(sim.particles[0].x, sim.particles[0].y,marker=".",color='r',linewidth=5)
plt.scatter(sim.particles[-1].x, sim.particles[-1].y,marker=".",color='g',linewidth=5)


ax = plt.subplot()
#ax.set_xlim([-4,4])
#ax.set_ylim([-4,4])
plt.scatter(xy[:,:,0],xy[:,:,1],marker=".",color='k',linewidth=0)

#The stuff in the colins are the particles on the plt.scatter plot

#put here

# %%
#Time/a,e,inc Graphs

import rebound
sim=rebound.Simulation()
sim.add(m=1.)
#sim.add(m=1, a=300, e=0.05)
#sim.move_to_com()
sim.integrator="whfast"
sim.dt=0.05
#test

import matplotlib.pyplot as plt

import numpy as np
Testparticle= 20
a_initial=np.linspace(10,50,Testparticle)
for a in a_initial:
    sim.add(a=a,f=np.random.rand()*2.*np.pi,e=0.05)

sim.add(m=1, a=300,e=0.05,inc=2.97)

sim.N_active=2


Time=200.*2*np.pi
N_out=15
xy=np.zeros((N_out,Testparticle,2))
times = np.linspace(100.*Time, 300.*Time, N_out)


# initialize a, e, and inc arrays
# each array is a matrix [i][j] where [i] refers to the time and [j] to the particle number (the primary is excluded)
a = np.zeros((N_out, sim.N-1))
e = np.zeros((N_out, sim.N-1))
inc = np.zeros((N_out, sim.N-1))


# loop over each timestep
for i,time in enumerate(times):
    sim.integrate(time, exact_finish_time=0)
    # loop over each particle
    for n in range(sim.N-1):
        m = n+1 # skip primary

        # here i'm assigning the quantities to the matrix I deifned above.
        a[i][n]=sim.particles[m].calculate_orbit(primary=sim.particles[0]).a
        e[i][n] = sim.particles[m].calculate_orbit(primary=sim.particles[0]).e
        inc[i][n] = sim.particles[m].calculate_orbit(primary=sim.particles[0]).inc

# %%
fig, ax = plt.subplots(figsize=(15,10), nrows = 3, ncols = 1)


# if i call a[:,:-1] it gives me all times (first entry) and all particles except the last one (which is the binary) (second entry of a)
ax[0].plot(times, a[:,:-1])
ax[1].plot(times, e[:,:-1])
ax[2].plot(times, inc[:,:-1])

ax[0].set(ylabel = 'a')
ax[1].set(ylabel = 'e')
ax[2].set(ylabel = 'i')

for axi in ax:
    axi.set(xlabel = 'time[years]')

# %%
sim.N
# Out:
# 6
